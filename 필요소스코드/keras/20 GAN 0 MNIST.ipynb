# %% [markdown]
# 랜덤 노이즈를 입력으로 받아 학습한 것과 비슷하지만 새로운 필기체 숫자 이미지를 출력하는 Generative Adversarial Network (GAN) 을 만들어 봅시다. 먼저 학습 이미지를 로드합니다. 레이블과 테스트 데이터는 필요하지 않습니다.

# %%
from tensorflow.keras import datasets, layers, models, utils, optimizers
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

(train_images, _), (_, _) = datasets.mnist.load_data()

print( 'train_images', type(train_images), train_images.shape, train_images.dtype )

plt.figure( figsize=(20,20) )
for i in range(0, 8*8):
    plt.subplot(8,8,i+1)
    plt.xticks([]); plt.yticks([])
    plt.imshow( train_images[i], cmap="gray" )
# Out:
# train_images <class 'numpy.ndarray'> (60000, 28, 28) uint8

# %% [markdown]
# 픽셀 값이 -1 에서 1 까지 나오도록 이미지를 정규화합니다.

# %%
_, H, W = train_images.shape
train_x = ( train_images.reshape(-1, H, W, 1) / 127.5 - 1 ).astype('float32')
print( 'train_x', type(train_x), train_x.shape, train_x.dtype )
# Out:
# train_x <class 'numpy.ndarray'> (60000, 28, 28, 1) float32

# %% [markdown]
# GAN 에 입력으로 들어갈 랜덤 노이즈를 생성하는 루틴을 만듭니다.

# %%
input_dim = 10
def gen_noise( batch_size ):
    return np.random.uniform( -1, 1, (batch_size, input_dim) )

# %% [markdown]
# 랜덤 노이즈를 입력받아 필기체 숫자를 생성하는 Generator (생성자)를 만듭니다. 아직 학습이 되지 않았기 때문에 노이즈 이미지가 생성되는것을 알 수 있습니다.

# %%
G = models.Sequential()

G.add( layers.Dense(7*7*128, input_dim=input_dim) )
G.add( layers.LeakyReLU(0.2) )
G.add( layers.Reshape((7, 7, 128)) )
G.add( layers.UpSampling2D(size=(2, 2)) )
G.add( layers.Conv2D(64, kernel_size=(5, 5), padding='same') )
G.add( layers.LeakyReLU(0.2) )
G.add( layers.UpSampling2D(size=(2, 2)) )
G.add( layers.Conv2D(1, kernel_size=(5, 5), padding='same', activation='tanh'))

G.summary()

generated = G.predict( gen_noise(16) )

plt.figure( figsize=(20,2) )

for i in range(16):
    plt.subplot(1,16,i+1)
    plt.xticks([]); plt.yticks([])
    plt.imshow( generated[i].reshape((H,W)) )
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6272)              68992
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 6272)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 64)        204864
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 1)         1601
# =================================================================
# Total params: 275,457
# Trainable params: 275,457
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 이미지를 입력받아 진짜인지 생성자가 생성한 가짜 이미지인지를 판별하는 Discriminator (판별자) 를 만듭니다. 진짜면 1, 가짜면 0 출력되기를 원하는데 아직 학습이 되지 않았으므로 원하는 출력결과가 나오지 않는다는 것을 알 수 있습니다.

# %%
D = models.Sequential()

D.add( layers.Conv2D(64, kernel_size=(5, 5), strides=(2, 2), padding='same',
                     input_shape=(H,W,1)))
D.add( layers.LeakyReLU(0.2) )
D.add( layers.Dropout(0.3) )
D.add( layers.Conv2D(128, kernel_size=(5, 5), strides=(2, 2), padding='same'))
D.add( layers.LeakyReLU(0.2) )
D.add( layers.Dropout(0.3) )
D.add( layers.Flatten())
D.add( layers.Dense(1, activation='sigmoid') )

optimizer = optimizers.Adam(lr=0.0002, beta_1=0.5)
D.compile(optimizer=optimizer, loss='binary_crossentropy')

D.summary()

print( D.predict( generated[0:3] ) )
print( D.predict( train_x[0:3] ) )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        1664
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 128)         204928
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6273
# =================================================================
# Total params: 212,865
# Trainable params: 212,865
# Non-trainable params: 0
# _________________________________________________________________
# [[0.49984533]
#  [0.500042  ]
#  [0.49956378]]
# [[0.5081989 ]
#  [0.5103722 ]
#  [0.49506664]]

# %% [markdown]
# 생성자에서 생성된 이미지가 판별자에게 입력으로 들어가는 네트워크를 만듭니다. 판별자를 고정시키고 생성자만 학습하기 위해서 판별자의 trainable 속성을 False 로 만들었습니다.

# %%
GD = models.Sequential()
GD.add(G)
GD.add(D)

D.trainable = False
GD.compile( optimizer=optimizer, loss='binary_crossentropy' )
GD.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 28, 28, 1)         275457
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 488,322
# Trainable params: 275,457
# Non-trainable params: 212,865
# _________________________________________________________________

# %% [markdown]
# 판별자를 학습시킬 때에는 실제 이미지와 가짜 이미지를 동시에 넣어주고 어느것이 진짜이고 가짜인지를 알려줍니다. 생성자를 학습시킬 때에는 판별자가 학습되지 않도록 판별자의 웨이트를 고정하고 생성자가 출력하는 이미지를 판별자가 진짜라고 판별하도록 학습을 시킵니다. 판별자와 생성자를 번갈아 가면서 학습을 시킵니다. 그러면 서로 발전해가면서 정교한 이미지가 생성이 됩니다.

# %%
def train_D( real_images ):
    batch_size = real_images.shape[0]
    generated_images = G.predict(gen_noise(batch_size))
    x = np.concatenate( (real_images, generated_images) )
    y = np.array( [1] * batch_size + [0] * batch_size )
    D.trainable = True
    D.train_on_batch( x, y )

def train_G( batch_size ):
    x = gen_noise( batch_size )
    y = np.array( [1]*batch_size )
    D.trainable = False
    GD.train_on_batch(x, y)

def test_and_show():
    generated = G.predict(gen_noise(16))
    plt.figure( figsize=(20,2) )
    for i in range(16):
        plt.subplot(1,16,i+1)
        plt.xticks([]); plt.yticks([])
        plt.imshow( generated[i].reshape((H,W)) )
    plt.show()

epochs = 50
batch_size = 256

print('epoch', 0, '/', epochs)
test_and_show()

for epoch in range(epochs):
    for i in range(0, train_x.shape[0], batch_size):
        train_D( train_x[i:i+batch_size] )
        train_G( batch_size )
    print('epoch', epoch+1, '/', epochs)
    test_and_show()
    
print( "Training finished" )
# Out:
# epoch 0 / 50
# epoch 1 / 50
# epoch 2 / 50
# epoch 3 / 50
# epoch 4 / 50
# epoch 5 / 50
# epoch 6 / 50
# epoch 7 / 50
# epoch 8 / 50
# epoch 9 / 50
# epoch 10 / 50
# epoch 11 / 50
# epoch 12 / 50
# epoch 13 / 50
# epoch 14 / 50
# epoch 15 / 50
# epoch 16 / 50
# epoch 17 / 50
# epoch 18 / 50
# epoch 19 / 50
# epoch 20 / 50
# epoch 21 / 50
# epoch 22 / 50
# epoch 23 / 50
# epoch 24 / 50
# epoch 25 / 50
# epoch 26 / 50
# epoch 27 / 50
# epoch 28 / 50
# epoch 29 / 50
# epoch 30 / 50
# epoch 31 / 50
# epoch 32 / 50
# epoch 33 / 50
# epoch 34 / 50
# epoch 35 / 50
# epoch 36 / 50
# epoch 37 / 50
# epoch 38 / 50
# epoch 39 / 50
# epoch 40 / 50
# epoch 41 / 50
# epoch 42 / 50
# epoch 43 / 50
# epoch 44 / 50
# epoch 45 / 50
# epoch 46 / 50
# epoch 47 / 50
# epoch 48 / 50
# epoch 49 / 50
# epoch 50 / 50
# Training finished
